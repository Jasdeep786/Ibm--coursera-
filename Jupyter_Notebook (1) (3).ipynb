# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jasdeep Singh**
# **Data Scientist**

# %% [markdown]
# *I am intrested in data science because I would love to contribute towards affordable and quality healthcare in the future*

# %% [markdown]
# ### The below should print 'Hello world'

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# --- This was realy
# 1. Easy
# 2. Clear
# 3. Simple
# 4. Fun
# </ol>**I suggest observor to see 'IBM Watson Studio' is down since too long, Please cheeck at your end href="https://cloud.ibm.com/">IBM Watson Studio I Tried more than once.
#
# |Date|Time|Success|
# |----|-----|------|
# |July12,2020|10.30pmIST|N July21,2020|09.00amIST|
#
#  Please find the below image of watson studio.
# ![Watson-Studio-785x295.jpg](attachment:efb0264d-14da-458d-b478-2272fa59fa63.jpg)
